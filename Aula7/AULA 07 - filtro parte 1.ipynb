# %%
import pandas as pd

# %%
df = pd.read_csv('country_vaccinations.csv')

# %%
df.head()
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
df.tail()
# Out:
#         country iso_code        date  total_vaccinations  people_vaccinated  \
# 25397  Zimbabwe      ZWE  2021-06-10           1089506.0           690452.0
# 25398  Zimbabwe      ZWE  2021-06-11           1096854.0           691251.0
# 25399  Zimbabwe      ZWE  2021-06-12           1103398.0           692180.0
# 25400  Zimbabwe      ZWE  2021-06-13           1107058.0           693147.0
# 25401  Zimbabwe      ZWE  2021-06-14           1108203.0           693568.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 25397                 399054.0                  5523.0              5857.0
# 25398                 405603.0                  7348.0              5802.0
# 25399                 411218.0                  6544.0              5921.0
# 25400                 413911.0                  3660.0              5564.0
# 25401                 414635.0                  1145.0              4890.0
#
# ...

# %%
df.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        1.426100e+04       1.353700e+04             1.079700e+04
# mean         8.934713e+06       4.661816e+06             2.636595e+06
# std          4.446220e+07       1.774606e+07             1.081268e+07
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          9.749600e+04       7.688300e+04             3.566200e+04
# 50%          6.815020e+05       5.050590e+05             2.737250e+05
# 75%          3.183324e+06       2.109961e+06             1.171026e+06
# max          9.902570e+08       6.220000e+08             2.232990e+08
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            1.179300e+04        2.510900e+04
# mean             1.991308e+05        1.007812e+05
# std              1.103274e+06        7.164128e+05
# min              0.000000e+00        0.000000e+00
# 25%              3.928000e+03        8.320000e+02
# ...

# %%
import missingno

# %%
missingno.matrix(df)

# %%
df.isna().any()
# Out:
# country                                False
# iso_code                               False
# date                                   False
# total_vaccinations                      True
# people_vaccinated                       True
# people_fully_vaccinated                 True
# daily_vaccinations_raw                  True
# daily_vaccinations                      True
# total_vaccinations_per_hundred          True
# people_vaccinated_per_hundred           True
# people_fully_vaccinated_per_hundred     True
# daily_vaccinations_per_million          True
# vaccines                               False
# source_name                            False
# source_website                         False
# dtype: bool

# %%
cols = df.columns[df.isna().any()].tolist()
cols
# Out:
# ['total_vaccinations',
#  'people_vaccinated',
#  'people_fully_vaccinated',
#  'daily_vaccinations_raw',
#  'daily_vaccinations',
#  'total_vaccinations_per_hundred',
#  'people_vaccinated_per_hundred',
#  'people_fully_vaccinated_per_hundred',
#  'daily_vaccinations_per_million']

# %%
df.isna().any(axis = 1)
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 25397    False
# 25398    False
# 25399    False
# 25400    False
# 25401    False
# Length: 25402, dtype: bool

# %%
df[df.isna().any(axis = 1)]
# Out:
#            country iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 25312     Zimbabwe      ZWE  2021-03-17             39607.0
# 25313     Zimbabwe      ZWE  2021-03-18             40002.0
# 25314     Zimbabwe      ZWE  2021-03-19             41687.0
# 25315     Zimbabwe      ZWE  2021-03-20             42210.0
# 25316     Zimbabwe      ZWE  2021-03-21             42729.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# 1                    NaN                      NaN                     NaN
# ...

# %%
df2 = df[df.notna().all(axis = 1)].reset_index(drop = True) 
df2.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        9.307000e+03       9.307000e+03             9.307000e+03
# mean         9.235001e+06       6.391077e+06             2.925374e+06
# std          3.111187e+07       2.092162e+07             1.149923e+07
# min          3.140000e+02       3.140000e+02             1.000000e+00
# 25%          3.172975e+05       2.497780e+05             5.279100e+04
# 50%          1.293486e+06       9.364970e+05             3.341870e+05
# 75%          5.017966e+06       3.552286e+06             1.303004e+06
# max          8.452990e+08       6.220000e+08             2.232990e+08
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            9.307000e+03        9.307000e+03
# mean             1.485887e+05        1.411903e+05
# std              4.574711e+05        4.158333e+05
# min              0.000000e+00        1.000000e+00
# 25%              6.122500e+03        7.826500e+03
# ...

# %%
df.dropna().describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        9.307000e+03       9.307000e+03             9.307000e+03
# mean         9.235001e+06       6.391077e+06             2.925374e+06
# std          3.111187e+07       2.092162e+07             1.149923e+07
# min          3.140000e+02       3.140000e+02             1.000000e+00
# 25%          3.172975e+05       2.497780e+05             5.279100e+04
# 50%          1.293486e+06       9.364970e+05             3.341870e+05
# 75%          5.017966e+06       3.552286e+06             1.303004e+06
# max          8.452990e+08       6.220000e+08             2.232990e+08
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            9.307000e+03        9.307000e+03
# mean             1.485887e+05        1.411903e+05
# std              4.574711e+05        4.158333e+05
# min              0.000000e+00        1.000000e+00
# 25%              6.122500e+03        7.826500e+03
# ...

# %%
df.head()
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
df[df['date']>'2021-04-26']
# Out:
#            country iso_code        date  total_vaccinations  \
# 64     Afghanistan      AFG  2021-04-27                 NaN
# 65     Afghanistan      AFG  2021-04-28                 NaN
# 66     Afghanistan      AFG  2021-04-29                 NaN
# 67     Afghanistan      AFG  2021-04-30                 NaN
# 68     Afghanistan      AFG  2021-05-01                 NaN
# ...            ...      ...         ...                 ...
# 25397     Zimbabwe      ZWE  2021-06-10           1089506.0
# 25398     Zimbabwe      ZWE  2021-06-11           1096854.0
# 25399     Zimbabwe      ZWE  2021-06-12           1103398.0
# 25400     Zimbabwe      ZWE  2021-06-13           1107058.0
# 25401     Zimbabwe      ZWE  2021-06-14           1108203.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 64                   NaN                      NaN                     NaN
# 65                   NaN                      NaN                     NaN
# ...

# %%
df[df['total_vaccinations']>=6000000]
# Out:
#              country iso_code        date  total_vaccinations  \
# 1005       Argentina      ARG  2021-04-16           6093016.0
# 1006       Argentina      ARG  2021-04-17           6226872.0
# 1007       Argentina      ARG  2021-04-18           6288812.0
# 1008       Argentina      ARG  2021-04-19           6334554.0
# 1009       Argentina      ARG  2021-04-20           6433141.0
# ...              ...      ...         ...                 ...
# 24499  United States      USA  2021-06-14         310645827.0
# 24500  United States      USA  2021-06-15         311886674.0
# 24501  United States      USA  2021-06-16         312915170.0
# 24502  United States      USA  2021-06-17         314969386.0
# 24503  United States      USA  2021-06-18         316048776.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 1005           5305604.0                 787412.0                157870.0
# ...
