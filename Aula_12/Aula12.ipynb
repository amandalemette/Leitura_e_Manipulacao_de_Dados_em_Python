# %%
import pandas as pd

# %%
df = pd.read_csv('country_vaccinations.csv')
df.head()
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
df = df.dropna().reset_index(drop=True)
df.head()
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-05-27            593313.0           479574.0
# 1  Afghanistan      AFG  2021-06-03            630305.0           481800.0
# 2      Albania      ALB  2021-02-18              3049.0             2438.0
# 3      Albania      ALB  2021-05-11            622507.0           440921.0
# 4      Albania      ALB  2021-05-12            632676.0           444755.0
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                 113739.0                  2859.0              6487.0
# 1                 148505.0                  4015.0              5285.0
# 2                    611.0                  1348.0               254.0
# 3                 181586.0                  9548.0             12160.0
# 4                 187921.0                 10169.0             10870.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
import missingno

# %%
missingno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
df.tail()
# Out:
#         country iso_code        date  total_vaccinations  people_vaccinated  \
# 13858  Zimbabwe      ZWE  2021-07-31           2413509.0          1645599.0
# 13859  Zimbabwe      ZWE  2021-08-01           2433341.0          1654112.0
# 13860  Zimbabwe      ZWE  2021-08-02           2473590.0          1674710.0
# 13861  Zimbabwe      ZWE  2021-08-03           2540555.0          1707671.0
# 13862  Zimbabwe      ZWE  2021-08-04           2604265.0          1740598.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 13858                 767910.0                 38148.0             42406.0
# 13859                 779229.0                 19832.0             43706.0
# 13860                 798880.0                 40249.0             42126.0
# 13861                 832884.0                 66965.0             46246.0
# 13862                 863667.0                 63710.0             46978.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13863 entries, 0 to 13862
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              13863 non-null  object
#  1   iso_code                             13863 non-null  object
#  2   date                                 13863 non-null  object
#  3   total_vaccinations                   13863 non-null  float64
#  4   people_vaccinated                    13863 non-null  float64
#  5   people_fully_vaccinated              13863 non-null  float64
#  6   daily_vaccinations_raw               13863 non-null  float64
#  7   daily_vaccinations                   13863 non-null  float64
#  8   total_vaccinations_per_hundred       13863 non-null  float64
#  9   people_vaccinated_per_hundred        13863 non-null  float64
#  10  people_fully_vaccinated_per_hundred  13863 non-null  float64
# ...

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13863 entries, 0 to 13862
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              13863 non-null  object
#  1   iso_code                             13863 non-null  object
#  2   date                                 13863 non-null  datetime64[ns]
#  3   total_vaccinations                   13863 non-null  float64
#  4   people_vaccinated                    13863 non-null  float64
#  5   people_fully_vaccinated              13863 non-null  float64
#  6   daily_vaccinations_raw               13863 non-null  float64
#  7   daily_vaccinations                   13863 non-null  float64
#  8   total_vaccinations_per_hundred       13863 non-null  float64
#  9   people_vaccinated_per_hundred        13863 non-null  float64
#  10  people_fully_vaccinated_per_hundred  13863 non-null  float64
# ...

# %%
df['date'].describe()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   """Entry point for launching an IPython kernel.
# count                   13863
# unique                    241
# top       2021-07-13 00:00:00
# freq                       98
# first     2020-12-11 00:00:00
# last      2021-08-08 00:00:00
# Name: date, dtype: object

# %%
df
# Out:
#            country iso_code       date  total_vaccinations  people_vaccinated  \
# 0      Afghanistan      AFG 2021-05-27            593313.0           479574.0
# 1      Afghanistan      AFG 2021-06-03            630305.0           481800.0
# 2          Albania      ALB 2021-02-18              3049.0             2438.0
# 3          Albania      ALB 2021-05-11            622507.0           440921.0
# 4          Albania      ALB 2021-05-12            632676.0           444755.0
# ...            ...      ...        ...                 ...                ...
# 13858     Zimbabwe      ZWE 2021-07-31           2413509.0          1645599.0
# 13859     Zimbabwe      ZWE 2021-08-01           2433341.0          1654112.0
# 13860     Zimbabwe      ZWE 2021-08-02           2473590.0          1674710.0
# 13861     Zimbabwe      ZWE 2021-08-03           2540555.0          1707671.0
# 13862     Zimbabwe      ZWE 2021-08-04           2604265.0          1740598.0
#
# ...

# %%
df['country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Andorra', 'Antigua and Barbuda',
#        'Argentina', 'Aruba', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belgium',
#        'Belize', 'Bhutan', 'Bolivia', 'Botswana', 'Brazil', 'Brunei',
#        'Bulgaria', 'Cambodia', 'Canada', 'Cape Verde', 'Cayman Islands',
#        'Chile', 'China', 'Colombia', 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Denmark', 'Dominica', 'Dominican Republic',
#        'Ecuador', 'Egypt', 'El Salvador', 'England', 'Estonia',
#        'Eswatini', 'Faeroe Islands', 'Finland', 'France',
#        'French Polynesia', 'Gabon', 'Georgia', 'Germany', 'Gibraltar',
#        'Greece', 'Greenland', 'Grenada', 'Guatemala', 'Guinea', 'Guyana',
#        'Haiti', 'Honduras', 'Hong Kong', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Ireland', 'Isle of Man', 'Israel', 'Italy',
#        'Japan', 'Jordan', 'Kazakhstan', 'Kenya', 'Kosovo', 'Kyrgyzstan',
# ...

# %%
len(df['country'].unique())
# Out:
# 150

# %%
paises = df['country'].unique().tolist()

# %%
paises
# Out:
# ['Afghanistan',
#  'Albania',
#  'Andorra',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belgium',
#  'Belize',
#  'Bhutan',
#  'Bolivia',
#  'Botswana',
#  'Brazil',
#  'Brunei',
#  'Bulgaria',
#  'Cambodia',
#  'Canada',
#  'Cape Verde',
#  'Cayman Islands',
#  'Chile',
#  'China',
#  'Colombia',
#  'Croatia',
#  'Cuba',
#  'Curacao',
#  'Cyprus',
#  'Czechia',
#  'Denmark',
#  'Dominica',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'England',
#  'Estonia',
#  'Eswatini',
#  'Faeroe Islands',
#  'Finland',
#  'France',
#  'French Polynesia',
#  'Gabon',
#  'Georgia',
#  'Germany',
#  'Gibraltar',
#  'Greece',
#  'Greenland',
#  'Grenada',
#  'Guatemala',
#  'Guinea',
#  'Guyana',
#  'Haiti',
#  'Honduras',
#  'Hong Kong',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Ireland',
#  'Isle of Man',
#  'Israel',
# ...

# %%
type(paises)
# Out:
# list

# %%
num_paises = len(paises)
num_paises
# Out:
# 150

# %%
df[df['country']==paises[1]]
# Out:
#     country iso_code       date  total_vaccinations  people_vaccinated  \
# 2   Albania      ALB 2021-02-18              3049.0             2438.0
# 3   Albania      ALB 2021-05-11            622507.0           440921.0
# 4   Albania      ALB 2021-05-12            632676.0           444755.0
# 5   Albania      ALB 2021-05-13            638338.0           445402.0
# 6   Albania      ALB 2021-05-14            653330.0           448571.0
# 7   Albania      ALB 2021-05-18            688947.0           460191.0
# 8   Albania      ALB 2021-05-19            697811.0           463402.0
# 9   Albania      ALB 2021-05-20            703743.0           466083.0
# 10  Albania      ALB 2021-05-21            708846.0           469169.0
# 11  Albania      ALB 2021-05-24            725135.0           475237.0
# 12  Albania      ALB 2021-05-27            759043.0           481788.0
# 13  Albania      ALB 2021-05-31            776461.0           486128.0
# ...

# %%
df[df['country']==paises[1]]['date'].max()
# Out:
# Timestamp('2021-08-05 00:00:00')

# %%
df[df['date']==df[df['country']==paises[1]]['date'].max()]
# Out:
#              country  iso_code       date  total_vaccinations  \
# 56           Albania       ALB 2021-08-05           1238036.0
# 253        Argentina       ARG 2021-08-05          33735965.0
# 340            Aruba       ABW 2021-08-05            139303.0
# 405        Australia       AUS 2021-08-05          13030257.0
# 610          Austria       AUT 2021-08-05           9889989.0
# ...              ...       ...        ...                 ...
# 13276  United States       USA 2021-08-05         348966419.0
# 13409        Uruguay       URY 2021-08-05           4862176.0
# 13478        Vietnam       VNM 2021-08-05           8061116.0
# 13684          Wales  OWID_WLS 2021-08-05           4399761.0
# 13726         Zambia       ZMB 2021-08-05            465760.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 56              693000.0                 545036.0                  8631.0
# ...

# %%
dff = pd.DataFrame()
for i in range(num_paises):
    dftemp = df.loc[(df['country']==paises[i])&
                    (df['date']==df[df['country']==paises[i]]['date'].max())]
    dff = pd.concat([dff,dftemp],ignore_index = True)

# %%
dff
# Out:
#                  country  iso_code       date  total_vaccinations  \
# 0            Afghanistan       AFG 2021-06-03            630305.0
# 1                Albania       ALB 2021-08-05           1238036.0
# 2                Andorra       AND 2021-04-05             15269.0
# 3    Antigua and Barbuda       ATG 2021-07-29             68850.0
# 4              Argentina       ARG 2021-08-08          34624926.0
# ..                   ...       ...        ...                 ...
# 145              Uruguay       URY 2021-08-08           4882131.0
# 146              Vietnam       VNM 2021-08-07           8896615.0
# 147                Wales  OWID_WLS 2021-08-07           4414285.0
# 148               Zambia       ZMB 2021-08-07            490441.0
# 149             Zimbabwe       ZWE 2021-08-04           2604265.0
#
#      people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0             481800.0                 148505.0                  4015.0
# ...
