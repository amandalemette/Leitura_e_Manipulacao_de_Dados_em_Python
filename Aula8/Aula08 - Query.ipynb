# %%
import pandas as pd

# %%
df = pd.read_csv('country_vaccinations.csv')

# %%
df.head()
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
df.tail()
# Out:
#         country iso_code        date  total_vaccinations  people_vaccinated  \
# 25397  Zimbabwe      ZWE  2021-06-10           1089506.0           690452.0
# 25398  Zimbabwe      ZWE  2021-06-11           1096854.0           691251.0
# 25399  Zimbabwe      ZWE  2021-06-12           1103398.0           692180.0
# 25400  Zimbabwe      ZWE  2021-06-13           1107058.0           693147.0
# 25401  Zimbabwe      ZWE  2021-06-14           1108203.0           693568.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 25397                 399054.0                  5523.0              5857.0
# 25398                 405603.0                  7348.0              5802.0
# 25399                 411218.0                  6544.0              5921.0
# 25400                 413911.0                  3660.0              5564.0
# 25401                 414635.0                  1145.0              4890.0
#
# ...

# %%
df.query('total_vaccinations <= 100')
# Out:
#            country iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 113        Albania      ALB  2021-01-10                 0.0
# 272        Algeria      DZA  2021-01-29                 0.0
# 273        Algeria      DZA  2021-01-30                30.0
# 542         Angola      AGO  2021-03-01                 0.0
# ...            ...      ...         ...                 ...
# 24692      Vanuatu      VUT  2021-06-01                 0.0
# 24707    Venezuela      VEN  2021-02-17                 0.0
# 24829      Vietnam      VNM  2021-03-07                 0.0
# 25222       Zambia      ZMB  2021-04-14                 0.0
# 25285     Zimbabwe      ZWE  2021-02-18                 0.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# 113                  0.0                      NaN                     NaN
# ...

# %%
df[df['total_vaccinations']<=100]
# Out:
#            country iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 113        Albania      ALB  2021-01-10                 0.0
# 272        Algeria      DZA  2021-01-29                 0.0
# 273        Algeria      DZA  2021-01-30                30.0
# 542         Angola      AGO  2021-03-01                 0.0
# ...            ...      ...         ...                 ...
# 24692      Vanuatu      VUT  2021-06-01                 0.0
# 24707    Venezuela      VEN  2021-02-17                 0.0
# 24829      Vietnam      VNM  2021-03-07                 0.0
# 25222       Zambia      ZMB  2021-04-14                 0.0
# 25285     Zimbabwe      ZWE  2021-02-18                 0.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# 113                  0.0                      NaN                     NaN
# ...

# %%
df.query('country == "Brazil"')
# Out:
#      country iso_code        date  total_vaccinations  people_vaccinated  \
# 3267  Brazil      BRA  2021-01-16                 0.0                0.0
# 3268  Brazil      BRA  2021-01-17               112.0              112.0
# 3269  Brazil      BRA  2021-01-18              1109.0             1109.0
# 3270  Brazil      BRA  2021-01-19             11470.0            11470.0
# 3271  Brazil      BRA  2021-01-20             28543.0            28543.0
# ...      ...      ...         ...                 ...                ...
# 3416  Brazil      BRA  2021-06-14          78906225.0         55226467.0
# 3417  Brazil      BRA  2021-06-15          80268207.0         56479200.0
# 3418  Brazil      BRA  2021-06-16          81540602.0         57676179.0
# 3419  Brazil      BRA  2021-06-17          84102155.0         60066656.0
# 3420  Brazil      BRA  2021-06-18          85390996.0         61270446.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...

# %%
df.query('country != "Brazil"')
# Out:
#            country iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 25397     Zimbabwe      ZWE  2021-06-10           1089506.0
# 25398     Zimbabwe      ZWE  2021-06-11           1096854.0
# 25399     Zimbabwe      ZWE  2021-06-12           1103398.0
# 25400     Zimbabwe      ZWE  2021-06-13           1107058.0
# 25401     Zimbabwe      ZWE  2021-06-14           1108203.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# 1                    NaN                      NaN                     NaN
# ...

# %%
df2 = df.query('country == "Brazil" & people_vaccinated >= 100000')

# %%
df2.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        1.310000e+02       1.310000e+02             1.150000e+02
# mean         2.906531e+07       2.065275e+07             9.581834e+06
# std          2.526206e+07       1.699133e+07             8.241064e+06
# min          1.365190e+05       1.365190e+05             1.962000e+03
# 25%          7.162708e+06       5.929976e+06             2.579786e+06
# 50%          2.063288e+07       1.609953e+07             6.035017e+06
# 75%          4.712040e+07       3.191181e+07             1.646253e+07
# max          8.539100e+07       6.127045e+07             2.412055e+07
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            1.230000e+02        1.310000e+02
# mean             5.601228e+05        5.242442e+05
# std              5.098781e+05        3.267984e+05
# min              1.849000e+03        2.730400e+04
# 25%              2.186935e+05        2.308310e+05
# ...

# %%
import numpy as np

# %%
np.unique(df2['country'])
# Out:
# array(['Brazil'], dtype=object)

# %%
df.head()
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
df.query('total_vaccinations > 1e6 | people_fully_vaccinated > 1e5')
# Out:
#            country iso_code        date  total_vaccinations  \
# 93     Afghanistan      AFG  2021-05-26            590454.0
# 94     Afghanistan      AFG  2021-05-27            593313.0
# 97     Afghanistan      AFG  2021-05-30            600152.0
# 100    Afghanistan      AFG  2021-06-02            626290.0
# 101    Afghanistan      AFG  2021-06-03            630305.0
# ...            ...      ...         ...                 ...
# 25397     Zimbabwe      ZWE  2021-06-10           1089506.0
# 25398     Zimbabwe      ZWE  2021-06-11           1096854.0
# 25399     Zimbabwe      ZWE  2021-06-12           1103398.0
# 25400     Zimbabwe      ZWE  2021-06-13           1107058.0
# 25401     Zimbabwe      ZWE  2021-06-14           1108203.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 93              479372.0                 111082.0                     NaN
# 94              479574.0                 113739.0                  2859.0
# ...

# %%
df.query('date >= "2021-06-01" & country == "Afghanistan"')
# Out:
#          country iso_code        date  total_vaccinations  people_vaccinated  \
# 99   Afghanistan      AFG  2021-06-01                 NaN                NaN
# 100  Afghanistan      AFG  2021-06-02            626290.0           481690.0
# 101  Afghanistan      AFG  2021-06-03            630305.0           481800.0
# 102  Afghanistan      AFG  2021-06-04                 NaN                NaN
# 103  Afghanistan      AFG  2021-06-05                 NaN                NaN
# 104  Afghanistan      AFG  2021-06-06                 NaN                NaN
# 105  Afghanistan      AFG  2021-06-07                 NaN                NaN
# 106  Afghanistan      AFG  2021-06-08            641295.0           482952.0
# 107  Afghanistan      AFG  2021-06-09                 NaN                NaN
# 108  Afghanistan      AFG  2021-06-10                 NaN                NaN
# 109  Afghanistan      AFG  2021-06-11                 NaN                NaN
# ...

# %%
df.query('date in ["2021-05-01","2021-05-31"]')
# Out:
#            country iso_code        date  total_vaccinations  \
# 68     Afghanistan      AFG  2021-05-01                 NaN
# 98     Afghanistan      AFG  2021-05-31                 NaN
# 224        Albania      ALB  2021-05-01            494028.0
# 254        Albania      ALB  2021-05-31            776461.0
# 364        Algeria      DZA  2021-05-01                 NaN
# ...            ...      ...         ...                 ...
# 25205        Yemen      YEM  2021-05-31                 NaN
# 25239       Zambia      ZMB  2021-05-01                 NaN
# 25269       Zambia      ZMB  2021-05-31                 NaN
# 25357     Zimbabwe      ZWE  2021-05-01            520299.0
# 25387     Zimbabwe      ZWE  2021-05-31           1020078.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 68                   NaN                      NaN                     NaN
# 98                   NaN                      NaN                     NaN
# ...
