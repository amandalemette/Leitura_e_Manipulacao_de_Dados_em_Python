# %%
import pandas as pd

# %%
df0 = pd.read_csv("coloncancer.txt", delim_whitespace = True)

# %%
df0.head()
# Out:
#    id  study       rx  sex  age  obstruct  perfor  adhere  nodes  status  \
# 0   1      1  Lev+5FU    1   43         0       0       0    5.0       1
# 1   1      1  Lev+5FU    1   43         0       0       0    5.0       1
# 2   2      1  Lev+5FU    1   63         0       0       0    1.0       0
# 3   2      1  Lev+5FU    1   63         0       0       0    1.0       0
# 4   3      1      Obs    0   71         0       0       1    7.0       1
#
#    differ  extent  surg  node4  time  etype
# 0     2.0       3     0      1  1521      2
# 1     2.0       3     0      1   968      1
# 2     2.0       3     0      0  3087      2
# 3     2.0       3     0      0  3087      1
# 4     2.0       2     0      1   963      2

# %%
df0.columns
# Out:
# Index(['id', 'study', 'rx', 'sex', 'age', 'obstruct', 'perfor', 'adhere',
#        'nodes', 'status', 'differ', 'extent', 'surg', 'node4', 'time',
#        'etype'],
#       dtype='object')

# %%
len(df0.columns)
# Out:
# 16

# %%
df0.tail()
# Out:
#        id  study       rx  sex  age  obstruct  perfor  adhere  nodes  status  \
# 1853  927      1      Lev    1   76         0       0       1    1.0       1
# 1854  928      1  Lev+5FU    0   48         1       0       0    4.0       0
# 1855  928      1  Lev+5FU    0   48         1       0       0    4.0       0
# 1856  929      1      Lev    0   66         1       0       0    1.0       0
# 1857  929      1      Lev    0   66         1       0       0    1.0       0
#
#       differ  extent  surg  node4  time  etype
# 1853     3.0       3     0      0   851      1
# 1854     2.0       3     1      1  2072      2
# 1855     2.0       3     1      1  2072      1
# 1856     2.0       3     0      0  1820      2
# 1857     2.0       3     0      0  1820      1

# %%
df0.describe()
# Out:
#                 id   study          sex          age     obstruct  \
# count  1858.000000  1858.0  1858.000000  1858.000000  1858.000000
# mean    465.000000     1.0     0.520990    59.754575     0.193757
# std     268.251243     0.0     0.499694    11.945670     0.395347
# min       1.000000     1.0     0.000000    18.000000     0.000000
# 25%     233.000000     1.0     0.000000    53.000000     0.000000
# 50%     465.000000     1.0     1.000000    61.000000     0.000000
# 75%     697.000000     1.0     1.000000    69.000000     0.000000
# max     929.000000     1.0     1.000000    85.000000     1.000000
#
#             perfor       adhere        nodes       status       differ  \
# count  1858.000000  1858.000000  1822.000000  1858.000000  1812.000000
# mean      0.029064     0.145318     3.659715     0.495156     2.062914
# std       0.168030     0.352516     3.571581     0.500111     0.514198
# min       0.000000     0.000000     0.000000     0.000000     1.000000
# ...

# %%
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1858 entries, 0 to 1857
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        1858 non-null   int64
#  1   study     1858 non-null   int64
#  2   rx        1858 non-null   object
#  3   sex       1858 non-null   int64
#  4   age       1858 non-null   int64
#  5   obstruct  1858 non-null   int64
#  6   perfor    1858 non-null   int64
#  7   adhere    1858 non-null   int64
#  8   nodes     1822 non-null   float64
#  9   status    1858 non-null   int64
#  10  differ    1812 non-null   float64
#  11  extent    1858 non-null   int64
#  12  surg      1858 non-null   int64
#  13  node4     1858 non-null   int64
#  14  time      1858 non-null   int64
#  15  etype     1858 non-null   int64
# dtypes: float64(2), int64(13), object(1)
# memory usage: 232.4+ KB

# %%
df1 = pd.read_csv("femalepopulation.txt")

# %%
df1.head()
# Out:
#           Country       2002      2003      2004      2005      2006  \
# 0       Australia  9887846.0   9999199  10100991  10218321  10348070
# 1         Austria  4179743.0   4158169   4190297   4220228   4246571
# 2         Belgium  5267437.0   5288959   5309245   5334527   5367561
# 3          Canada        NaN  15829173  15834015  16146667  16303914
# 4  Czech Republic  5264218.0   5236563   5236715   5239664   5248431
#
#        2007      2008      2009      2010      2011      2012
# 0  10570420  10770864  10986535  11218144  11359807  11402769
# 1   4261752   4277716   4287213   4296197   4308915   4324983
# 2   5403126   5442557   5484429   5527684   4996609   5622157
# 3  16478759  16601231  16802833  16807738  17101813  17379104
# 4   5261005   5298196   5331165   5349616   5363971   5347235

# %%
df1.tail()
# Out:
#            Country         2002       2003       2004       2005       2006  \
# 25          Sweden    4500683.0    4513681    4529014    4545081    4561202
# 26     Switzerland    3712121.0    3738824    3762609    3786406    3806626
# 27          Turkey          NaN   34753495   35023500   35484500   35945763
# 28  United Kingdom   29753779.0   30331409   30506793   30664861   30817364
# 29   United States  141943484.0  146817188  147773459  149495099  150913782
#
#          2007       2008       2009       2010       2011       2012
# 25    4589734    4619006    4652637    4691668    4725326    4756021
# 26    3829380    3866480    3915181    3955240    3992708    4032409
# 27   35945763   35209723   35615946   36098842   36679806   37191315
# 28   30976313   31145537   31331174   31518326   31726030   32115485
# 29  152261670  154509976  154662649  155915671  157539944  158635141

# %%
len(df1.columns)
# Out:
# 12

# %%
df1.describe()
# Out:
#                2002          2003          2004          2005          2006  \
# count  2.800000e+01  3.000000e+01  3.000000e+01  3.000000e+01  3.000000e+01
# mean   1.878752e+07  1.946601e+07  1.957595e+07  1.974024e+07  1.986934e+07
# std    2.940416e+07  2.929550e+07  2.947588e+07  2.975716e+07  3.000057e+07
# min    1.431250e+05  1.441840e+05  1.451690e+05  1.464070e+05  1.486890e+05
# 25%    2.753824e+06  3.010597e+06  3.017349e+06  3.025100e+06  3.031638e+06
# 50%    5.340921e+06  5.467506e+06  5.492313e+06  5.515518e+06  5.535432e+06
# 75%    2.509346e+07  2.811592e+07  2.832822e+07  2.855097e+07  2.867601e+07
# max    1.419435e+08  1.468172e+08  1.477735e+08  1.494951e+08  1.509138e+08
#
#                2007          2008          2009          2010          2011  \
# count  3.000000e+01  3.000000e+01  3.000000e+01  3.000000e+01  3.000000e+01
# mean   1.998341e+07  2.010803e+07  2.020393e+07  2.031434e+07  2.045895e+07
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 12 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  30 non-null     object
#  1    2002    28 non-null     float64
#  2   2003     30 non-null     int64
#  3   2004     30 non-null     int64
#  4   2005     30 non-null     int64
#  5   2006     30 non-null     int64
#  6   2007     30 non-null     int64
#  7   2008     30 non-null     int64
#  8   2009     30 non-null     int64
#  9   2010     30 non-null     int64
#  10  2011     30 non-null     int64
#  11  2012     30 non-null     int64
# dtypes: float64(1), int64(10), object(1)
# memory usage: 2.9+ KB

# %%
df1['Country']
# Out:
# 0           Australia
# 1             Austria
# 2             Belgium
# 3              Canada
# 4      Czech Republic
# 5             Denmark
# 6             Finland
# 7              France
# 8             Germany
# 9              Greece
# 10            Hungary
# 11            Iceland
# 12            Ireland
# 13              Italy
# 14              Japan
# 15              Korea
# 16         Luxembourg
# 17             Mexico
# 18        Netherlands
# 19        New Zealand
# 20             Norway
# 21             Poland
# 22           Portugal
# 23    Slovak Republic
# 24              Spain
# 25             Sweden
# 26        Switzerland
# 27             Turkey
# 28     United Kingdom
# 29      United States
# Name: Country, dtype: object

# %%
df0.to_csv('coloncancer.dat',index = False)
df1.to_csv('femalepopulation.dat',index = False)

# %%
pd.read_csv('coloncancer.dat')
# Out:
#        id  study       rx  sex  age  obstruct  perfor  adhere  nodes  status  \
# 0       1      1  Lev+5FU    1   43         0       0       0    5.0       1
# 1       1      1  Lev+5FU    1   43         0       0       0    5.0       1
# 2       2      1  Lev+5FU    1   63         0       0       0    1.0       0
# 3       2      1  Lev+5FU    1   63         0       0       0    1.0       0
# 4       3      1      Obs    0   71         0       0       1    7.0       1
# ...   ...    ...      ...  ...  ...       ...     ...     ...    ...     ...
# 1853  927      1      Lev    1   76         0       0       1    1.0       1
# 1854  928      1  Lev+5FU    0   48         1       0       0    4.0       0
# 1855  928      1  Lev+5FU    0   48         1       0       0    4.0       0
# 1856  929      1      Lev    0   66         1       0       0    1.0       0
# 1857  929      1      Lev    0   66         1       0       0    1.0       0
#
# ...

# %%
pd.read_csv('femalepopulation.dat')
# Out:
#             Country         2002       2003       2004       2005       2006  \
# 0         Australia    9887846.0    9999199   10100991   10218321   10348070
# 1           Austria    4179743.0    4158169    4190297    4220228    4246571
# 2           Belgium    5267437.0    5288959    5309245    5334527    5367561
# 3            Canada          NaN   15829173   15834015   16146667   16303914
# 4    Czech Republic    5264218.0    5236563    5236715    5239664    5248431
# 5           Denmark    2714208.0    2721084    2727505    2734113    2741613
# 6           Finland    2657304.0    2661379    2666839    2674534    2683230
# 7            France   30510073.0   30655533   30789154   32147490   32390087
# 8           Germany   42165633.0   42191801   42175657   42147222   42098034
# 9            Greece    5547887.0    5557795    5576249    5596119    5617014
# 10          Hungary    5337873.0    5323906    5312629    5304434    5292002
# ...
